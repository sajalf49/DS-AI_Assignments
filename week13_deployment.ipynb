# %% [markdown]
# <a href="https://colab.research.google.com/github/sajalf49/DS-AI_Assignments/blob/main/week13_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13: Model Deployment
# ## Readings
# - Flask ML Deployment Guide
# - FastAPI Official Documentation
#
# ## Class Task
# - Build and run a simple ML model API using Flask or FastAPI.
#
# ## Assignment 13
# - Deploy your trained model on localhost or Google Colab.
#
# ## Project Milestone
# - End-to-end pipeline working.

# %% [markdown]
# ## Example: Simple Flask API

# %%
from flask import Flask, request, jsonify
import joblib

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.json
    model = joblib.load('model.pkl')
    prediction = model.predict([data['features']])
    return jsonify({'prediction': int(prediction[0])})

# Run: app.run(host='0.0.0.0', port=5000)

# %% [markdown]
# ## Example: Simple FastAPI

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import joblib

class InputData(BaseModel):
    features: list

app = FastAPI()

@app.post('/predict')
def predict(data: InputData):
    model = joblib.load('model.pkl')
    prediction = model.predict([data.features])
    return {'prediction': int(prediction[0])}

# Run with: uvicorn filename:app --reload
